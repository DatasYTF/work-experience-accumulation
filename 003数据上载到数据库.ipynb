# %%
import numpy as np
import pandas as pd
import time

# %%
start_time = time.time()
df = pd.read_csv('./文件/001订单明细.csv',low_memory=False)
end_time = time.time()
print("读取用时{}s".format(end_time - start_time))
# Out:
# 读取用时27.519030332565308s

# %%
df.shape
# Out:
# (3223195, 40)

# %%
start_time = time.time()

import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import sqlalchemy
engine = create_engine("mysql://root:keepfit@localhost/erp",
                                encoding='utf-8')

df.to_sql('001订单明细', con=engine, if_exists='replace', index=False,
#              dtype={'运单号': sqlalchemy.types.String(length=20),
#                     '受理时间': sqlalchemy.types.DateTime(),
#                    '发件人手机': sqlalchemy.types.String(length=80),
#                    '发件人电话': sqlalchemy.types.String(length=80),
#                    '客户批次号': sqlalchemy.types.String(length=80),
#                    '收件人手机': sqlalchemy.types.String(length=80),
#                    '收件人电话': sqlalchemy.types.String(length=80),
#                    '数量': sqlalchemy.types.String(length=80)})
             dtype={'运单号': sqlalchemy.types.String(length=20),
                    '受理时间': sqlalchemy.types.TIMESTAMP(),
                   '发件人手机': sqlalchemy.types.String(length=80),
                   '发件人电话': sqlalchemy.types.String(length=80),
                   '客户批次号': sqlalchemy.types.String(length=80),
                    "公司地址": sqlalchemy.types.String(length=255),
                   '收件人手机': sqlalchemy.types.String(length=80),
                   '收件人电话': sqlalchemy.types.String(length=80),
                   '写入人工号': sqlalchemy.types.String(length=80),
                   '数量': sqlalchemy.types.String(length=200)})

end_time = time.time()
print("上传用时{}s".format(end_time - start_time))
# Out:
# 上传用时875.1610560417175s
